# %%
import pandas as pd

# %%
df = pd.read_csv("Furnace Draw.csv")

# %%
df
# Out:
#           Date  Furnace\nDraw\n(MT)  Cullet %
# 0    01-Apr-21                  162      22.0
# 1    02-Apr-21                  162      21.0
# 2    03-Apr-21                  163      20.0
# 3    04-Apr-21                  163      20.0
# 4    05-Apr-21                  163      20.0
# ..         ...                  ...       ...
# 335  02-Mar-22                  161      30.0
# 336  03-Mar-22                  154      30.0
# 337  04-Mar-22                  156      30.0
# 338  05-Mar-22                  158      30.0
# 339  06-Mar-22                  155      30.0
#
# [340 rows x 3 columns]

# %%
df1 = pd.read_csv("Flat_File_Furnace_Level_wthout_CE_data.csv")
df1 = df1.drop("Unnamed: 0", axis=1)

# %%
df1
# Out:
#                  Date Time  \
# 0      2021-01-13 13:00:00
# 1      2021-01-13 13:00:00
# 2      2021-01-13 13:00:00
# 3      2021-01-13 13:00:00
# 4      2021-01-13 13:00:00
# ...                    ...
# 45357  2022-01-01 06:00:00
# 45358  2022-01-01 06:00:00
# 45359  2022-01-01 06:00:00
# 45360  2022-01-01 06:00:00
# 45361  2022-01-01 06:00:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.942957
# 2                                            1249.942957
# 3                                            1249.942957
# 4                                            1249.942957
# ...                                                  ...
# 45357                                        1253.574451
# 45358                                        1253.574451
# 45359                                        1253.574451
# ...

# %%
df1["Date_"] = pd.to_datetime(df1["Date Time"]).dt.date

# %%
df1["Date_"] = pd.to_datetime(df1["Date_"])
df1
# Out:
#                  Date Time  \
# 0      2021-01-13 13:00:00
# 1      2021-01-13 13:00:00
# 2      2021-01-13 13:00:00
# 3      2021-01-13 13:00:00
# 4      2021-01-13 13:00:00
# ...                    ...
# 45357  2022-01-01 06:00:00
# 45358  2022-01-01 06:00:00
# 45359  2022-01-01 06:00:00
# 45360  2022-01-01 06:00:00
# 45361  2022-01-01 06:00:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.942957
# 2                                            1249.942957
# 3                                            1249.942957
# 4                                            1249.942957
# ...                                                  ...
# 45357                                        1253.574451
# 45358                                        1253.574451
# 45359                                        1253.574451
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
df
# Out:
#           Date  Furnace\nDraw\n(MT)  Cullet %
# 0   2021-04-01                  162      22.0
# 1   2021-04-02                  162      21.0
# 2   2021-04-03                  163      20.0
# 3   2021-04-04                  163      20.0
# 4   2021-04-05                  163      20.0
# ..         ...                  ...       ...
# 335 2022-03-02                  161      30.0
# 336 2022-03-03                  154      30.0
# 337 2022-03-04                  156      30.0
# 338 2022-03-05                  158      30.0
# 339 2022-03-06                  155      30.0
#
# [340 rows x 3 columns]

# %%
df.rename(columns={'Furnace\nDraw\n(MT)': 'Furnace Draw'}, inplace=True)
df
# Out:
#           Date  Furnace Draw  Cullet %
# 0   2021-04-01           162      22.0
# 1   2021-04-02           162      21.0
# 2   2021-04-03           163      20.0
# 3   2021-04-04           163      20.0
# 4   2021-04-05           163      20.0
# ..         ...           ...       ...
# 335 2022-03-02           161      30.0
# 336 2022-03-03           154      30.0
# 337 2022-03-04           156      30.0
# 338 2022-03-05           158      30.0
# 339 2022-03-06           155      30.0
#
# [340 rows x 3 columns]

# %%
df3 = pd.merge(df1, df, how="left", left_on = "Date_", right_on="Date")
df3 = df3.drop("Date_y", axis=1)
df3 = df3.drop("Date_", axis=1)
df3 = df3.drop("Unnamed: 0", axis=1)
df3.rename(columns={'Date_x': 'Date'}, inplace=True)

# %%
df3
# Out:
#                       Date  \
# 0      2021-01-01 07:00:00
# 1      2021-01-01 07:00:00
# 2      2021-01-01 07:00:00
# 3      2021-01-01 07:00:00
# 4      2021-01-01 07:00:00
# ...                    ...
# 58393  2021-12-31 23:00:00
# 58394  2021-12-31 23:00:00
# 58395  2021-12-31 23:00:00
# 58396  2021-12-31 23:00:00
# 58397  2021-12-31 23:00:00
#
#        DCS_160TPD_CHIMANY_DRAFT_PRESSURE_MEASURMENT_CHMYDRFTPTAI32  \
# 0                                             -54.042479
# 1                                             -54.042479
# 2                                             -54.042479
# 3                                             -54.042479
# 4                                             -54.042479
# ...                                                  ...
# 58393                                         -49.912128
# 58394                                         -49.912128
# 58395                                         -49.912128
# ...

# %%
df3["Date"] = pd.to_datetime(df3["Date"])

# %%
# df4 = pd.read_excel("Draw and Cullet percentage (1).xlsx")
# df4 = df4.drop("250 TPD", axis=1)
# df4 = df4.drop("Unnamed: 5", axis=1)
# df4

# %%
# new_header = df4.iloc[0]  # grab the first row for the header
# df4 = df4[1:]  # take the data less the header row
# df4.columns = new_header
# df4

# %%
# df4["Date"] = pd.to_datetime(df4["Date"]).dt.date

# %%
# df4["Date"] = df4["Date"].astype(str)

# %%
# df4.to_csv("Cullet_Information_160_Tpd.csv")

# %%
# df4 = pd.read_csv("Cullet_Information_160_Tpd.csv")
# df4.info()

# %%
# df4["Date"] = pd.to_datetime(df4["Date"]+ " " + df4["Time"])

# %%
# df4 = df4.drop("Unnamed: 0", axis=1)
# # df4 =df4.drop("Time", axis=1)

# %%
# df4["Date"] = pd.to_datetime(df4["Date"]).dt.round("1h")

# %%
# df4.head(20)

# %%
# df5 = pd.merge(df3, df4, how="left", on ="Date")
# df5

# %%
# df5.to_csv("Flat_File_with_Draw_and_Cullet.csv")

# %%
# df5 = pd.read_csv("160tpd/Flat_File_with_Draw_and_Cullet.csv")

# %%
# df5

# %%
# df5["Date"] = pd.to_datetime(df5["Date"])

# %%
df6 = pd.read_csv("ce_setout_R.csv")
df6 = df6.drop("Unnamed: 0", axis=1)
df6.rename(columns = {"From":"Date"}, inplace = True)

# %%
df6
# Out:
#                     Date LineName JobNumber  PONumber  SampleSize  DefectCode  \
# 0       07-04-2021 13:30       R2    J20042   1022558          50         506
# 1       07-04-2021 13:30       R2    J20042   1022558          50         250
# 2       07-04-2021 13:30       R2    J20042   1022558          50         100
# 3       07-04-2021 13:30       R2    J20042   1022558          50         123
# 4       16-06-2021 02:30       R2    J21265   1024069          50         220
# ...                  ...      ...       ...       ...         ...         ...
# 184395  20-10-2021 06:30      S19    J23505   1026400          50         226
# 184396  20-10-2021 06:30      S19    J23505   1026400          50         506
# 184397  20-10-2021 06:30      S19    J23505   1026400          50         506
# 184398  08-04-2021 07:30      S17    J20062   1022867          50         220
# 184399  21-06-2021 22:30      S16    J21240   1024018         100         201
#
# ...

# %%
df6 = df6.drop(["JobNumber", "PONumber",
               "DefectCode"], axis=1)

# %%
df6
# Out:
#                     Date LineName  SampleSize  DefectCount              Name
# 0       07-04-2021 13:30       R2          50            1           BLISTER
# 1       07-04-2021 13:30       R2          50            2      LOADING MARK
# 2       07-04-2021 13:30       R2          50            1        HEAD CRACK
# 3       07-04-2021 13:30       R2          50            1        TONG CHECK
# 4       16-06-2021 02:30       R2          50            1          LAP MARK
# ...                  ...      ...         ...          ...               ...
# 184395  20-10-2021 06:30      S19          50            3  OIL SPOTS (MARK)
# 184396  20-10-2021 06:30      S19          50            2           BLISTER
# 184397  20-10-2021 06:30      S19          50            2           BLISTER
# 184398  08-04-2021 07:30      S17          50            1          LAP MARK
# 184399  21-06-2021 22:30      S16         100            1    SHOULDER CRACK
#
# [184400 rows x 5 columns]

# %%
df6 = df6[df6["Name"]!="BREAKAGE"]

# %%
# df6 = df6.loc[df6['Name'].isin(['Bubble (>2.5 mm)', 'BLISTER'])]
# df6

# %%
df6
# Out:
#                     Date LineName  SampleSize  DefectCount              Name
# 0       07-04-2021 13:30       R2          50            1           BLISTER
# 1       07-04-2021 13:30       R2          50            2      LOADING MARK
# 2       07-04-2021 13:30       R2          50            1        HEAD CRACK
# 3       07-04-2021 13:30       R2          50            1        TONG CHECK
# 4       16-06-2021 02:30       R2          50            1          LAP MARK
# ...                  ...      ...         ...          ...               ...
# 184395  20-10-2021 06:30      S19          50            3  OIL SPOTS (MARK)
# 184396  20-10-2021 06:30      S19          50            2           BLISTER
# 184397  20-10-2021 06:30      S19          50            2           BLISTER
# 184398  08-04-2021 07:30      S17          50            1          LAP MARK
# 184399  21-06-2021 22:30      S16         100            1    SHOULDER CRACK
#
# [182489 rows x 5 columns]

# %%
df6["Date"] = df6["Date"]+" "+df6["Time"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-6d891329d589> in <module>
# ----> 1 df6["Date"] = df6["Date"]+" "+df6["Time"]
#
# ...

# %%
# df6 = df6.drop("Time", axis=1)
df6 = df6.drop("Name", axis=1)

# %%
df6
# Out:
#                     Date LineName  SampleSize  DefectCount
# 0       07-04-2021 13:30       R2          50            1
# 1       07-04-2021 13:30       R2          50            2
# 2       07-04-2021 13:30       R2          50            1
# 3       07-04-2021 13:30       R2          50            1
# 4       16-06-2021 02:30       R2          50            1
# ...                  ...      ...         ...          ...
# 184395  20-10-2021 06:30      S19          50            3
# 184396  20-10-2021 06:30      S19          50            2
# 184397  20-10-2021 06:30      S19          50            2
# 184398  08-04-2021 07:30      S17          50            1
# 184399  21-06-2021 22:30      S16         100            1
#
# [182489 rows x 4 columns]

# %%
df6 = df6.groupby(["Date", "LineName"])["SampleSize", "DefectCount"].sum().reset_index()
# Out:
# C:\Users\Rishav\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df6
# Out:
#                    Date LineName  SampleSize  DefectCount
# 0      01-01-2021 00:30      S14        1200           17
# 1      01-01-2021 00:30      S17         100            4
# 2      01-01-2021 00:30      S18         250            6
# 3      01-01-2021 01:30      S14        1400           20
# 4      01-01-2021 01:30      S18         200            6
# ...                 ...      ...         ...          ...
# 19620  31-12-2021 21:30      S19         450           23
# 19621  31-12-2021 22:30      S17         300           14
# 19622  31-12-2021 22:30      S19         450           20
# 19623  31-12-2021 23:30       R1         250            9
# 19624  31-12-2021 23:30      S15        2400           30
#
# [19625 rows x 4 columns]

# %%
df1["Date Time"] = pd.to_datetime(df1["Date Time"])

# %%
df6["Date"] = pd.to_datetime(df6["Date"]).dt.round("1h")

# %%
df6
# Out:
#                      Date LineName  SampleSize  DefectCount
# 0     2021-01-01 00:00:00      S14        1200           17
# 1     2021-01-01 00:00:00      S17         100            4
# 2     2021-01-01 00:00:00      S18         250            6
# 3     2021-01-01 02:00:00      S14        1400           20
# 4     2021-01-01 02:00:00      S18         200            6
# ...                   ...      ...         ...          ...
# 19620 2021-12-31 22:00:00      S19         450           23
# 19621 2021-12-31 22:00:00      S17         300           14
# 19622 2021-12-31 22:00:00      S19         450           20
# 19623 2022-01-01 00:00:00       R1         250            9
# 19624 2022-01-01 00:00:00      S15        2400           30
#
# [19625 rows x 4 columns]

# %%
df6["Date"] = df6["Date"] - pd.Timedelta(hours=1)
df6
# Out:
#                      Date LineName  SampleSize  DefectCount
# 0     2020-12-31 23:00:00      S14        1200           17
# 1     2020-12-31 23:00:00      S17         100            4
# 2     2020-12-31 23:00:00      S18         250            6
# 3     2021-01-01 01:00:00      S14        1400           20
# 4     2021-01-01 01:00:00      S18         200            6
# ...                   ...      ...         ...          ...
# 19620 2021-12-31 21:00:00      S19         450           23
# 19621 2021-12-31 21:00:00      S17         300           14
# 19622 2021-12-31 21:00:00      S19         450           20
# 19623 2021-12-31 23:00:00       R1         250            9
# 19624 2021-12-31 23:00:00      S15        2400           30
#
# [19625 rows x 4 columns]

# %%
df7 = pd.merge(df1, df6, how="left", left_on=["Date Time", "Line"], right_on = ["Date", "LineName"])

# %%
df7= df7.drop("LineName", axis=1)
df7 = df7.drop("Date_",axis=1)
df7 = df7.drop("Date", axis=1)
df7
# Out:
#                 Date Time  \
# 0     2021-01-13 13:00:00
# 1     2021-01-13 13:00:00
# 2     2021-01-13 13:00:00
# 3     2021-01-13 13:00:00
# 4     2021-01-13 13:00:00
# ...                   ...
# 46833 2022-01-01 06:00:00
# 46834 2022-01-01 06:00:00
# 46835 2022-01-01 06:00:00
# 46836 2022-01-01 06:00:00
# 46837 2022-01-01 06:00:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.942957
# 2                                            1249.942957
# 3                                            1249.942957
# 4                                            1249.942957
# ...                                                  ...
# 46833                                        1253.574451
# 46834                                        1253.574451
# 46835                                        1253.574451
# 46836                                        1253.574451
# ...

# %%
df8 = pd.read_csv("job_plan_30min_R.csv", encoding="ISO-8859–1")
# Out:
# C:\Users\Rishav\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df8
# Out:
#         Unnamed: 0            StartTime              EndTime     Id  \
# 0                0  2020-09-17 18:30:00  2020-09-17 19:00:00  16372
# 1                1  2020-09-17 19:00:00  2020-09-17 19:30:00  16372
# 2                2  2020-09-17 19:30:00  2020-09-17 20:00:00  16372
# 3                3  2020-09-17 20:00:00  2020-09-17 20:30:00  16372
# 4                4  2020-09-17 20:30:00  2020-09-17 21:00:00  16372
# ...            ...                  ...                  ...    ...
# 196235      196235  2022-02-07 13:30:00  2022-02-07 14:00:00  25574
# 196236      196236  2022-02-07 14:00:00  2022-02-07 14:30:00  25574
# 196237      196237  2022-02-07 14:30:00  2022-02-07 15:00:00  25574
# 196238      196238  2022-02-07 15:00:00  2022-02-07 15:30:00  25574
# 196239      196239  2022-02-07 15:30:00  2022-02-07 16:00:00  25574
#
#                                   Identifier LineName  Number  \
# 0       7c794b6a-5b1f-4985-bdf6-df318e23348a       R1  J16372
# ...

# %%
df8 = df8[["StartTime", "EndTime", "LineName", "Number", "Name", "FGCode", "NumberOfSection", "NumberOfGob",
           "GobCutPerMinute", "ISMachineActualSpeed", "GobWeightLow", "GobWeightHigh", "GlassDraw", "PackedQunatity", "Classification", "ProductionOrderNumber"]]
df8
# Out:
#                   StartTime              EndTime LineName  Number  \
# 0       2020-09-17 18:30:00  2020-09-17 19:00:00       R1  J16372
# 1       2020-09-17 19:00:00  2020-09-17 19:30:00       R1  J16372
# 2       2020-09-17 19:30:00  2020-09-17 20:00:00       R1  J16372
# 3       2020-09-17 20:00:00  2020-09-17 20:30:00       R1  J16372
# 4       2020-09-17 20:30:00  2020-09-17 21:00:00       R1  J16372
# ...                     ...                  ...      ...     ...
# 196235  2022-02-07 13:30:00  2022-02-07 14:00:00      S19  J25574
# 196236  2022-02-07 14:00:00  2022-02-07 14:30:00      S19  J25574
# 196237  2022-02-07 14:30:00  2022-02-07 15:00:00      S19  J25574
# 196238  2022-02-07 15:00:00  2022-02-07 15:30:00      S19  J25574
# 196239  2022-02-07 15:30:00  2022-02-07 16:00:00      S19  J25574
#
#                                           Name              FGCode  \
# 0                         100 ML ZC MRS - EB54  F3V2251QJPQ000001M
# ...

# %%
df8["StartTime"] = pd.to_datetime(df8["StartTime"])
df8["EndTime"] = pd.to_datetime(df8["EndTime"])
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196240 entries, 0 to 196239
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   StartTime              196226 non-null  datetime64[ns]
#  1   EndTime                196226 non-null  datetime64[ns]
#  2   LineName               196240 non-null  object
#  3   Number                 196240 non-null  object
#  4   Name                   196240 non-null  object
#  5   FGCode                 196240 non-null  object
#  6   NumberOfSection        196240 non-null  int64
#  7   NumberOfGob            196240 non-null  int64
#  8   GobCutPerMinute        196240 non-null  float64
#  9   ISMachineActualSpeed   196240 non-null  float64
#  10  GobWeightLow           196240 non-null  float64
#  11  GobWeightHigh          196240 non-null  float64
#  12  GlassDraw              196240 non-null  float64
#  13  PackedQunatity         195143 non-null  float64
# ...

# %%
# df8 = df8[["StartTime", "FGCode", "LineName"]]
df8
# Out:
#                  StartTime             EndTime LineName  Number  \
# 0      2020-09-17 18:30:00 2020-09-17 19:00:00       R1  J16372
# 1      2020-09-17 19:00:00 2020-09-17 19:30:00       R1  J16372
# 2      2020-09-17 19:30:00 2020-09-17 20:00:00       R1  J16372
# 3      2020-09-17 20:00:00 2020-09-17 20:30:00       R1  J16372
# 4      2020-09-17 20:30:00 2020-09-17 21:00:00       R1  J16372
# ...                    ...                 ...      ...     ...
# 196235 2022-02-07 13:30:00 2022-02-07 14:00:00      S19  J25574
# 196236 2022-02-07 14:00:00 2022-02-07 14:30:00      S19  J25574
# 196237 2022-02-07 14:30:00 2022-02-07 15:00:00      S19  J25574
# 196238 2022-02-07 15:00:00 2022-02-07 15:30:00      S19  J25574
# 196239 2022-02-07 15:30:00 2022-02-07 16:00:00      S19  J25574
#
#                                           Name              FGCode  \
# 0                         100 ML ZC MRS - EB54  F3V2251QJPQ000001M
# ...

# %%
df9 = pd.merge(df7, df8,  how='left', left_on=[
    'Date Time', 'Line'], right_on=['StartTime', 'LineName'])

# %%
df9 = df9.drop(["StartTime","LineName", "Name", "Number", "EndTime", "Classification", "ProductionOrderNumber"], axis=1)

# %%
df9
# Out:
#                 Date Time  \
# 0     2021-01-13 13:00:00
# 1     2021-01-13 13:00:00
# 2     2021-01-13 13:00:00
# 3     2021-01-13 13:00:00
# 4     2021-01-13 13:00:00
# ...                   ...
# 56265 2022-01-01 06:00:00
# 56266 2022-01-01 06:00:00
# 56267 2022-01-01 06:00:00
# 56268 2022-01-01 06:00:00
# 56269 2022-01-01 06:00:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.942957
# 2                                            1249.942957
# 3                                            1249.942957
# 4                                            1249.942957
# ...                                                  ...
# 56265                                        1253.574451
# 56266                                        1253.574451
# 56267                                        1253.574451
# 56268                                        1253.574451
# ...

# %%
df9["FGCode"].value_counts()[:1]
# Out:
# F3T1891QHLQ020001P    6913
# Name: FGCode, dtype: int64

# %%
df9_ = dict(df9["FGCode"].value_counts()[:1])
li = [k for k,v in df9_.items()]
li
# Out:
# ['F3T1891QHLQ020001P']

# %%
df9 = df9[df9["FGCode"].isin(li)].reset_index()
df9 = df9.drop(["FGCode", "index"], axis=1)
df9
# Out:
#                Date Time  \
# 0    2021-01-13 13:00:00
# 1    2021-01-13 13:00:00
# 2    2021-01-13 14:00:00
# 3    2021-01-13 14:00:00
# 4    2021-01-13 15:00:00
# ...                  ...
# 6908 2022-01-01 02:00:00
# 6909 2022-01-01 03:00:00
# 6910 2022-01-01 04:00:00
# 6911 2022-01-01 05:00:00
# 6912 2022-01-01 06:00:00
#
#       Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                           1249.942957
# 1                                           1249.942957
# 2                                           1250.104159
# 3                                           1250.104159
# 4                                           1249.835071
# ...                                                 ...
# 6908                                        1254.971057
# 6909                                        1254.964791
# 6910                                        1255.027974
# 6911                                        1254.836511
# ...

# %%
df9.to_csv("Flat_File_Forehearth_Level_Total-Breakage_top_sku.csv")
