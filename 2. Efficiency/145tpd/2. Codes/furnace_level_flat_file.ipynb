# %%
import pandas as pd

# %%
df = pd.read_csv("DCS_data_145_tpd.csv")

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed: 0')]
df
# Out:
#                  Date Time  \
# 0      2021-01-13 13:00:00
# 1      2021-01-13 13:30:00
# 2      2021-01-13 14:00:00
# 3      2021-01-13 14:30:00
# 4      2021-01-13 15:00:00
# ...                    ...
# 18772  2022-03-12 13:30:00
# 18773  2022-03-12 14:00:00
# 18774  2022-03-12 14:30:00
# 18775  2022-03-12 15:00:00
# 18776  2022-03-12 15:30:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.997579
# 2                                            1250.104159
# 3                                            1250.053035
# 4                                            1249.835071
# ...                                                  ...
# 18772                                        1239.985522
# 18773                                        1240.087769
# 18774                                        1239.976351
# ...

# %%
df1 = pd.read_csv("rm_composition_R.csv")

# %%
df1.describe()
# Out:
#        Unnamed: 0  chem_comp_SiO2  chem_comp_Al2O3  chem_comp_Fe2O3  \
# count  454.000000      454.000000       454.000000       454.000000
# mean   226.500000       71.530749         1.976542         0.023258
# std    131.202769        0.643175         0.225131         0.004097
# min      0.000000       69.120000         1.610000         0.011000
# 25%    113.250000       71.442500         1.920000         0.021000
# 50%    226.500000       71.720000         1.950000         0.023800
# 75%    339.750000       71.910000         2.020000         0.026000
# max    453.000000       72.400000         4.940000         0.043000
#
#        chem_comp_CaO  chem_comp_MgO  chem_comp_Na2O  chem_comp_K2O  \
# count     454.000000     454.000000      454.000000     454.000000
# mean        8.615088       1.988326       13.490859       0.503833
# std         0.782229       0.195964        0.346588       0.334944
# min         1.230000       0.550000        8.470000       0.000000
# ...

# %%
df1 = df1.loc[:, ~df1.columns.str.contains('^Unnamed: 0')]
# df1 = df1.groupby("glass_properties_date", as_index=False).mean()
# print(df1["physical_test_seed_count_result"][199])

# %%
df["Date_"] = pd.to_datetime(df["Date Time"]).dt.date

# %%
df["Date_"] = pd.to_datetime(df["Date_"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18777 entries, 0 to 18776
# Columns: 228 entries, Date Time to Date_
# dtypes: datetime64[ns](1), float64(226), object(1)
# memory usage: 32.7+ MB

# %%
df
# Out:
#                  Date Time  \
# 0      2021-01-13 13:00:00
# 1      2021-01-13 13:30:00
# 2      2021-01-13 14:00:00
# 3      2021-01-13 14:30:00
# 4      2021-01-13 15:00:00
# ...                    ...
# 18772  2022-03-12 13:30:00
# 18773  2022-03-12 14:00:00
# 18774  2022-03-12 14:30:00
# 18775  2022-03-12 15:00:00
# 18776  2022-03-12 15:30:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.997579
# 2                                            1250.104159
# 3                                            1250.053035
# 4                                            1249.835071
# ...                                                  ...
# 18772                                        1239.985522
# 18773                                        1240.087769
# 18774                                        1239.976351
# ...

# %%
df1_ = df1.groupby("glass_properties_date").mean().reset_index()

# %%
df1_
# Out:
#     glass_properties_date  chem_comp_SiO2  chem_comp_Al2O3  chem_comp_Fe2O3  \
# 0              01-01-2020           70.65            2.100            0.014
# 1              01-01-2021           72.01            1.895            0.026
# 2              01-01-2022           71.52            1.970            0.021
# 3              01-02-2021           72.11            1.930            0.025
# 4              01-03-2021           71.65            1.920            0.023
# ..                    ...             ...              ...              ...
# 314            31-07-2020           71.37            2.040            0.025
# 315            31-07-2021           72.07            1.950            0.027
# 316            31-08-2020           71.81            2.010            0.023
# 317            31-10-2021           71.54            1.970            0.022
# 318            31-12-2020           71.96            1.740            0.030
#
# ...

# %%
df1_["glass_properties_date"] = pd.to_datetime(df1_["glass_properties_date"])

# %%
df3 = pd.merge(df, df1_, how='left',
               left_on='Date_', right_on='glass_properties_date')

# %%
df3 = df3.drop("glass_properties_date", axis=1)
df3
# Out:
#                  Date Time  \
# 0      2021-01-13 13:00:00
# 1      2021-01-13 13:30:00
# 2      2021-01-13 14:00:00
# 3      2021-01-13 14:30:00
# 4      2021-01-13 15:00:00
# ...                    ...
# 18772  2022-03-12 13:30:00
# 18773  2022-03-12 14:00:00
# 18774  2022-03-12 14:30:00
# 18775  2022-03-12 15:00:00
# 18776  2022-03-12 15:30:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.997579
# 2                                            1250.104159
# 3                                            1250.053035
# 4                                            1249.835071
# ...                                                  ...
# 18772                                        1239.985522
# 18773                                        1240.087769
# 18774                                        1239.976351
# ...

# %%
df3_ = df3.drop("Date_", axis=1)

# %%
df3_["Date Time"] = pd.to_datetime(df3_["Date Time"])
df3_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18777 entries, 0 to 18776
# Columns: 237 entries, Date Time to physical_test_seed_count_result
# dtypes: datetime64[ns](1), float64(236)
# memory usage: 34.1 MB

# %%
df3_
# Out:
#                 Date Time  \
# 0     2021-01-13 13:00:00
# 1     2021-01-13 13:30:00
# 2     2021-01-13 14:00:00
# 3     2021-01-13 14:30:00
# 4     2021-01-13 15:00:00
# ...                   ...
# 18772 2022-03-12 13:30:00
# 18773 2022-03-12 14:00:00
# 18774 2022-03-12 14:30:00
# 18775 2022-03-12 15:00:00
# 18776 2022-03-12 15:30:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.997579
# 2                                            1250.104159
# 3                                            1250.053035
# 4                                            1249.835071
# ...                                                  ...
# 18772                                        1239.985522
# 18773                                        1240.087769
# 18774                                        1239.976351
# 18775                                        1240.022668
# ...

# %%
df4 = pd.read_csv("Efficiency_combined_data_R.csv")

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'TimeStamp', 'Month', 'Furnace', 'Line', 'Hour',
#        'Material Number', 'Segment', 'Material description', 'Section', 'GOB',
#        'Actual Start', 'Actual End', 'ActPackedQty', 'Uncleared Qty',
#        'Std Eff.', 'Clrd Eff', 'Act BPM', 'Bud. Price', 'ActWght',
#        'Order Number', 'Plant', 'Order Type', 'Total Days', 'DPR Eff',
#        'Std Value', 'ActDrw(Ton)', 'Total DPR Qty', 'RvsdActGobCut',
#        'DPR PckTon', 'DPR Value', 'Run Date', 'Old Material', 'Non Std',
#        'Prod Clr Qty', 'Prod Uclr Qty', 'StdPackedQty', 'Rvsd Std Eff',
#        'Pckd Eff', 'Prod Clrd Eff', 'Std BPM', 'Rvsd Std Pckd Qty',
#        'RvsdStdBPM', 'StdWght', 'Crew', 'PassedQty', 'Shift', 'Pckd Value',
#        'Shift-Date', 'StdDrw(Ton)', 'Run Days', 'Quality Fail', 'Cumm.Days',
#        'Other Fail', 'Clrd Value', 'StdPckTon', 'ExpctdQtyFrmFail',
#        'Unclrd Value', 'ActPckTon', 'ActDrwTon/Day', 'ActClrdTon', 'StdGobCut',
# ...

# %%
df4 = df4[["Date", "TimeStamp", "Furnace", "Line", "DPR Eff", "ActDrw(Ton)"]]

# %%
df4
# Out:
#              Date TimeStamp  Furnace Line  DPR Eff  ActDrw(Ton)
# 0      2021-01-01   8:00:00      145  S14    89.51         1.00
# 1      2021-01-01   9:00:00      145  S14    89.51         1.00
# 2      2021-01-01  10:00:00      145  S14    84.66         1.00
# 3      2021-01-01  11:00:00      145  S14    89.51         1.00
# 4      2021-01-01  12:00:00      145  S14    89.51         1.00
# ...           ...       ...      ...  ...      ...          ...
# 53239  2022-01-01   6:00:00      145  S16    52.47         0.59
# 53240  2022-01-01   6:00:00      145  S17    78.47         0.99
# 53241  2021-12-31   7:00:00      145  S16    54.44         0.59
# 53242  2021-12-31   7:00:00      145  S17    85.12         0.99
# 53243  2021-12-31   7:00:00      145  S18    24.30         1.36
#
# [53244 rows x 6 columns]

# %%
df4["Date"] = pd.to_datetime(df4['Date'].astype(
    str) + ' ' + df4['TimeStamp'].astype(str))
df4
# Out:
#                      Date TimeStamp  Furnace Line  DPR Eff  ActDrw(Ton)
# 0     2021-01-01 08:00:00   8:00:00      145  S14    89.51         1.00
# 1     2021-01-01 09:00:00   9:00:00      145  S14    89.51         1.00
# 2     2021-01-01 10:00:00  10:00:00      145  S14    84.66         1.00
# 3     2021-01-01 11:00:00  11:00:00      145  S14    89.51         1.00
# 4     2021-01-01 12:00:00  12:00:00      145  S14    89.51         1.00
# ...                   ...       ...      ...  ...      ...          ...
# 53239 2022-01-01 06:00:00   6:00:00      145  S16    52.47         0.59
# 53240 2022-01-01 06:00:00   6:00:00      145  S17    78.47         0.99
# 53241 2021-12-31 07:00:00   7:00:00      145  S16    54.44         0.59
# 53242 2021-12-31 07:00:00   7:00:00      145  S17    85.12         0.99
# 53243 2021-12-31 07:00:00   7:00:00      145  S18    24.30         1.36
#
# [53244 rows x 6 columns]

# %%
df4_ = df4.drop("TimeStamp", axis =1)
df4_ = df4_.drop("Furnace", axis = 1)

# %%
df4_
# Out:
#                      Date Line  DPR Eff  ActDrw(Ton)
# 0     2021-01-01 08:00:00  S14    89.51         1.00
# 1     2021-01-01 09:00:00  S14    89.51         1.00
# 2     2021-01-01 10:00:00  S14    84.66         1.00
# 3     2021-01-01 11:00:00  S14    89.51         1.00
# 4     2021-01-01 12:00:00  S14    89.51         1.00
# ...                   ...  ...      ...          ...
# 53239 2022-01-01 06:00:00  S16    52.47         0.59
# 53240 2022-01-01 06:00:00  S17    78.47         0.99
# 53241 2021-12-31 07:00:00  S16    54.44         0.59
# 53242 2021-12-31 07:00:00  S17    85.12         0.99
# 53243 2021-12-31 07:00:00  S18    24.30         1.36
#
# [53244 rows x 4 columns]

# %%
# df4_ = df4_.groupby(['Date']).agg(
#     mean_DPR_eff=('DPR Eff', 'mean'),
# ).reset_index()

# %%
df4_
# Out:
#                      Date Line  DPR Eff  ActDrw(Ton)
# 0     2021-01-01 08:00:00  S14    89.51         1.00
# 1     2021-01-01 09:00:00  S14    89.51         1.00
# 2     2021-01-01 10:00:00  S14    84.66         1.00
# 3     2021-01-01 11:00:00  S14    89.51         1.00
# 4     2021-01-01 12:00:00  S14    89.51         1.00
# ...                   ...  ...      ...          ...
# 53239 2022-01-01 06:00:00  S16    52.47         0.59
# 53240 2022-01-01 06:00:00  S17    78.47         0.99
# 53241 2021-12-31 07:00:00  S16    54.44         0.59
# 53242 2021-12-31 07:00:00  S17    85.12         0.99
# 53243 2021-12-31 07:00:00  S18    24.30         1.36
#
# [53244 rows x 4 columns]

# %%
df4_["Date"] = pd.to_datetime(df4_["Date"])

# %%
df5 = pd.merge(df3_ , df4_,how = 'left', left_on = "Date Time", right_on="Date")
df5
# Out:
#                 Date Time  \
# 0     2021-01-13 13:00:00
# 1     2021-01-13 13:00:00
# 2     2021-01-13 13:00:00
# 3     2021-01-13 13:00:00
# 4     2021-01-13 13:00:00
# ...                   ...
# 57185 2022-03-12 13:30:00
# 57186 2022-03-12 14:00:00
# 57187 2022-03-12 14:30:00
# 57188 2022-03-12 15:00:00
# 57189 2022-03-12 15:30:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.942957
# 2                                            1249.942957
# 3                                            1249.942957
# 4                                            1249.942957
# ...                                                  ...
# 57185                                        1239.985522
# 57186                                        1240.087769
# 57187                                        1239.976351
# 57188                                        1240.022668
# ...

# %%
df5 = df5.drop("Date", axis=1)

# %%
df5
# Out:
#                 Date Time  \
# 0     2021-01-13 13:00:00
# 1     2021-01-13 13:00:00
# 2     2021-01-13 13:00:00
# 3     2021-01-13 13:00:00
# 4     2021-01-13 13:00:00
# ...                   ...
# 57185 2022-03-12 13:30:00
# 57186 2022-03-12 14:00:00
# 57187 2022-03-12 14:30:00
# 57188 2022-03-12 15:00:00
# 57189 2022-03-12 15:30:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.942957
# 2                                            1249.942957
# 3                                            1249.942957
# 4                                            1249.942957
# ...                                                  ...
# 57185                                        1239.985522
# 57186                                        1240.087769
# 57187                                        1239.976351
# 57188                                        1240.022668
# ...

# %%
# df5.mean_DPR_eff.isnull().sum()

# %%
df5 = df5[df5["DPR Eff"].isnull()==False]

# %%
df5
# Out:
#                 Date Time  \
# 0     2021-01-13 13:00:00
# 1     2021-01-13 13:00:00
# 2     2021-01-13 13:00:00
# 3     2021-01-13 13:00:00
# 4     2021-01-13 13:00:00
# ...                   ...
# 53806 2022-01-01 06:00:00
# 53807 2022-01-01 06:00:00
# 53808 2022-01-01 06:00:00
# 53809 2022-01-01 06:00:00
# 53810 2022-01-01 06:00:00
#
#        Fiber Optic Thermometer -F/H61- Crank _DB223,DD134,QC  \
# 0                                            1249.942957
# 1                                            1249.942957
# 2                                            1249.942957
# 3                                            1249.942957
# 4                                            1249.942957
# ...                                                  ...
# 53806                                        1253.574451
# 53807                                        1253.574451
# 53808                                        1253.574451
# 53809                                        1253.574451
# ...

# %%
df5.to_csv("Flat_File_Furnace_Level_wthout_CE_data.csv")

# %%
df6 = pd.read_csv("ce_setout_final_pruned_R.csv")

# %%
df6
# Out:
#       Unnamed: 0            TimeStamp LineName JobNumber  DefectCountSum  \
# 0              0  2021-01-01 01:30:00      J16    J18183              16
# 1              1  2021-01-01 01:30:00      J19    J18093              24
# 2              2  2021-01-01 02:30:00      J17    J18152              24
# 3              3  2021-01-01 02:30:00      J18    J18094              23
# 4              4  2021-01-01 03:30:00      J20    J18165              22
# ...          ...                  ...      ...       ...             ...
# 8800        8800  2022-12-01 04:30:00      J15    J25062              16
# 8801        8801  2022-12-01 04:30:00      J18    J25018              20
# 8802        8802  2022-12-01 04:30:00      J19    J25063              18
# 8803        8803  2022-12-01 05:30:00      J18    J25018              22
# 8804        8804  2022-12-01 22:30:00      J20    J24974              13
#
#       SampleSizeSum
# 0              1300
# 1              1800
# 2              1800
# ...

# %%
df6 = df6.drop("JobNumber", axis =1)

# %%
df6["TimeStamp"] = pd.to_datetime(df6["TimeStamp"])

# %%
df6 = df6.loc[:, ~df6.columns.str.contains('^Unnamed')]
df6['TimeStamp'] = df6['TimeStamp'].dt.round('H')

# %%
df6
# Out:
#                TimeStamp LineName  DefectCountSum  SampleSizeSum
# 0    2021-01-01 02:00:00      J16              16           1300
# 1    2021-01-01 02:00:00      J19              24           1800
# 2    2021-01-01 02:00:00      J17              24           1800
# 3    2021-01-01 02:00:00      J18              23           1800
# 4    2021-01-01 04:00:00      J20              22            450
# ...                  ...      ...             ...            ...
# 8800 2022-12-01 04:00:00      J15              16           1100
# 8801 2022-12-01 04:00:00      J18              20           2000
# 8802 2022-12-01 04:00:00      J19              18           1600
# 8803 2022-12-01 06:00:00      J18              22           2000
# 8804 2022-12-01 22:00:00      J20              13            350
#
# [8805 rows x 4 columns]

# %%
df6["TimeStamp"] = df6["TimeStamp"] - pd.Timedelta(hours=1)

# %%
df6
# Out:
#                TimeStamp LineName  DefectCountSum  SampleSizeSum
# 0    2021-01-01 01:00:00      J16              16           1300
# 1    2021-01-01 01:00:00      J19              24           1800
# 2    2021-01-01 01:00:00      J17              24           1800
# 3    2021-01-01 01:00:00      J18              23           1800
# 4    2021-01-01 03:00:00      J20              22            450
# ...                  ...      ...             ...            ...
# 8800 2022-12-01 03:00:00      J15              16           1100
# 8801 2022-12-01 03:00:00      J18              20           2000
# 8802 2022-12-01 03:00:00      J19              18           1600
# 8803 2022-12-01 05:00:00      J18              22           2000
# 8804 2022-12-01 21:00:00      J20              13            350
#
# [8805 rows x 4 columns]

# %%
# df6_ = df6.groupby(['TimeStamp']).agg(
#     Defect_Count=('DefectCountSum', 'sum'),
#     Sample_Size = ("SampleSizeSum", "sum")
# ).reset_index()

# %%
df6
# Out:
#                TimeStamp LineName  DefectCountSum  SampleSizeSum
# 0    2021-01-01 01:00:00      J16              16           1300
# 1    2021-01-01 01:00:00      J19              24           1800
# 2    2021-01-01 01:00:00      J17              24           1800
# 3    2021-01-01 01:00:00      J18              23           1800
# 4    2021-01-01 03:00:00      J20              22            450
# ...                  ...      ...             ...            ...
# 8800 2022-12-01 03:00:00      J15              16           1100
# 8801 2022-12-01 03:00:00      J18              20           2000
# 8802 2022-12-01 03:00:00      J19              18           1600
# 8803 2022-12-01 05:00:00      J18              22           2000
# 8804 2022-12-01 21:00:00      J20              13            350
#
# [8805 rows x 4 columns]

# %%
df6["TimeStamp"] = pd.to_datetime(df6["TimeStamp"])

# %%
df7 = pd.merge(df5, df6, how="left", left_on = ["Date", "Line"] , right_on=["TimeStamp", "LineName"])

# %%
df7
# Out:
#                      Date  \
# 0     2021-01-01 07:00:00
# 1     2021-01-01 07:00:00
# 2     2021-01-01 07:00:00
# 3     2021-01-01 07:00:00
# 4     2021-01-01 07:00:00
# ...                   ...
# 59066 2021-12-31 23:00:00
# 59067 2021-12-31 23:00:00
# 59068 2021-12-31 23:00:00
# 59069 2021-12-31 23:00:00
# 59070 2021-12-31 23:00:00
#
#        DCS_160TPD_CHIMANY_DRAFT_PRESSURE_MEASURMENT_CHMYDRFTPTAI32  \
# 0                                             -54.042479
# 1                                             -54.042479
# 2                                             -54.042479
# 3                                             -54.042479
# 4                                             -54.042479
# ...                                                  ...
# 59066                                         -49.912128
# 59067                                         -49.912128
# 59068                                         -49.912128
# ...

# %%
df7 = df7.drop("TimeStamp", axis =1)
df7 = df7.drop("LineName", axis =1)

# %%
df7
# Out:
#                      Date  \
# 0     2021-01-01 07:00:00
# 1     2021-01-01 07:00:00
# 2     2021-01-01 07:00:00
# 3     2021-01-01 07:00:00
# 4     2021-01-01 07:00:00
# ...                   ...
# 59066 2021-12-31 23:00:00
# 59067 2021-12-31 23:00:00
# 59068 2021-12-31 23:00:00
# 59069 2021-12-31 23:00:00
# 59070 2021-12-31 23:00:00
#
#        DCS_160TPD_CHIMANY_DRAFT_PRESSURE_MEASURMENT_CHMYDRFTPTAI32  \
# 0                                             -54.042479
# 1                                             -54.042479
# 2                                             -54.042479
# 3                                             -54.042479
# 4                                             -54.042479
# ...                                                  ...
# 59066                                         -49.912128
# 59067                                         -49.912128
# 59068                                         -49.912128
# ...

# %%
df8 = pd.read_csv("job_plan_R_30min.csv", encoding="ISO-8859–1")
# Out:
# C:\Users\Rishav\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df8.columns
# Out:
# Index(['Unnamed: 0', 'StartTime', 'EndTime', 'Id', 'Identifier', 'LineName',
#        'Number', 'Name', 'FGCode', 'NumberOfSection', 'NumberOfGob',
#        'GobCutPerMinute', 'ISMachineActualSpeed', 'GobWeightLow',
#        'GobWeightHigh', 'GlassDraw', 'LehrTime', 'StandardEfficiency',
#        'BestEfficiency', 'RequiredQuantity', 'Status', 'ActualStartTime',
#        'ActualEndTime', 'NumberOfBottlePerPack', 'TotalProductionInCount',
#        'TotalProductionInPercentage', 'TotalProductionInTon', 'TenantCode',
#        'IsDeleted', 'PackedQunatity', 'Speed', 'ExpectedTime',
#        'RemainingQuantity', 'ProductionOrderNumber', 'NumberOfSectionB',
#        'NumberOfGobB', 'AQLIdentifier', 'QualityPlanFileURL',
#        'BottlesDrawingFileURL', 'JobRunningMode', 'JobChangeStartTime',
#        'NumberOfPacksPerPalette', 'AQLCode', 'InspectionLotNumber',
#        'GobWeight', 'PlantCode', 'StandardEfficiencyAchievedDate',
#        'ExpectedJobChangeTime', 'Classification'],
# ...

# %%
df8 = df8[["StartTime", "EndTime", "LineName", "Number", "Name", "FGCode", "NumberOfSection", "NumberOfGob",
           "GobCutPerMinute", "ISMachineActualSpeed", "GobWeightLow", "GobWeightHigh", "GlassDraw", "PackedQunatity", "Classification", "ProductionOrderNumber"]]
df8
# Out:
#                StartTime           EndTime LineName  Number  \
# 0       01-01-2021 16:00  01-01-2021 16:30      J13  J18166
# 1       01-01-2021 16:30  01-01-2021 17:00      J13  J18166
# 2       01-01-2021 17:00  01-01-2021 17:30      J13  J18166
# 3       01-01-2021 17:30  01-01-2021 18:00      J13  J18166
# 4       01-01-2021 18:00  01-01-2021 18:30      J13  J18166
# ...                  ...               ...      ...     ...
# 174646  08-02-2022 13:00  08-02-2022 13:30      J20  J25498
# 174647  08-02-2022 13:30  08-02-2022 14:00      J20  J25498
# 174648  08-02-2022 14:00  08-02-2022 14:30      J20  J25498
# 174649  08-02-2022 14:30  08-02-2022 15:00      J20  J25498
# 174650  08-02-2022 15:00  08-02-2022 15:30      J20  J25498
#
#                                             Name              FGCode  \
# 0                  32.000 OZ BSTN RD SHELF STK F  F3Z0691QRQQ000002X
# 1                  32.000 OZ BSTN RD SHELF STK F  F3Z0691QRQQ000002X
# ...

# %%
df8["StartTime"] = pd.to_datetime(df8["StartTime"])
df8["EndTime"] = pd.to_datetime(df8["EndTime"])
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174651 entries, 0 to 174650
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   StartTime              174649 non-null  datetime64[ns]
#  1   EndTime                174649 non-null  datetime64[ns]
#  2   LineName               174651 non-null  object
#  3   Number                 174651 non-null  object
#  4   Name                   174651 non-null  object
#  5   FGCode                 174651 non-null  object
#  6   NumberOfSection        174651 non-null  int64
#  7   NumberOfGob            174651 non-null  int64
#  8   GobCutPerMinute        174651 non-null  int64
#  9   ISMachineActualSpeed   174651 non-null  float64
#  10  GobWeightLow           174651 non-null  int64
#  11  GobWeightHigh          174651 non-null  int64
#  12  GlassDraw              174651 non-null  float64
#  13  PackedQunatity         174476 non-null  float64
# ...

# %%
df9 = pd.merge(df7, df8,  how='left', left_on=[
    'Date', 'Line'], right_on=['StartTime', 'LineName'])

# %%
df9 = df9.drop(["StartTime", "EndTime", "LineName"], axis =1)

# %%
df9
# Out:
#                      Date  \
# 0     2021-01-01 07:00:00
# 1     2021-01-01 07:00:00
# 2     2021-01-01 07:00:00
# 3     2021-01-01 07:00:00
# 4     2021-01-01 07:00:00
# ...                   ...
# 78502 2021-12-31 23:00:00
# 78503 2021-12-31 23:00:00
# 78504 2021-12-31 23:00:00
# 78505 2021-12-31 23:00:00
# 78506 2021-12-31 23:00:00
#
#        DCS_160TPD_CHIMANY_DRAFT_PRESSURE_MEASURMENT_CHMYDRFTPTAI32  \
# 0                                             -54.042479
# 1                                             -54.042479
# 2                                             -54.042479
# 3                                             -54.042479
# 4                                             -54.042479
# ...                                                  ...
# 78502                                         -49.912128
# 78503                                         -49.912128
# 78504                                         -49.912128
# ...

# %%
df9_DPR = df9[df9["DPR Eff"].isnull() == False]
df9_DPR = df9_DPR[df9_DPR["Line"]=="J13"]
df9_DPR = df9_DPR.drop("Line", axis =1)
df9_DPR
# Out:
#                      Date  \
# 3     2021-01-01 07:00:00
# 10    2021-01-01 07:00:00
# 19    2021-01-01 08:00:00
# 26    2021-01-01 08:00:00
# 34    2021-01-01 09:00:00
# ...                   ...
# 78459 2021-12-31 19:00:00
# 78469 2021-12-31 20:00:00
# 78486 2021-12-31 21:00:00
# 78490 2021-12-31 22:00:00
# 78504 2021-12-31 23:00:00
#
#        DCS_160TPD_CHIMANY_DRAFT_PRESSURE_MEASURMENT_CHMYDRFTPTAI32  \
# 3                                             -54.042479
# 10                                            -54.042479
# 19                                            -53.451039
# 26                                            -53.451039
# 34                                            -53.750758
# ...                                                  ...
# 78459                                         -49.708068
# 78469                                         -50.082470
# 78486                                         -49.487463
# ...

# %%
df9_DPR = df9_DPR.reset_index(drop = True)

# %%
df9_DPR
# Out:
#                      Date  \
# 0     2021-01-01 07:00:00
# 1     2021-01-01 07:00:00
# 2     2021-01-01 08:00:00
# 3     2021-01-01 08:00:00
# 4     2021-01-01 09:00:00
# ...                   ...
# 10883 2021-12-31 19:00:00
# 10884 2021-12-31 20:00:00
# 10885 2021-12-31 21:00:00
# 10886 2021-12-31 22:00:00
# 10887 2021-12-31 23:00:00
#
#        DCS_160TPD_CHIMANY_DRAFT_PRESSURE_MEASURMENT_CHMYDRFTPTAI32  \
# 0                                             -54.042479
# 1                                             -54.042479
# 2                                             -53.451039
# 3                                             -53.451039
# 4                                             -53.750758
# ...                                                  ...
# 10883                                         -49.708068
# 10884                                         -50.082470
# 10885                                         -49.487463
# ...

# %%
df9_DPR.to_csv("Flat_File_Forehearth_Level_DPR_Eff_J13.csv")

# %%
df9_DefectCount = df9_DPR[df9_DPR["DefectCountSum"].isnull() == False]

# %%
df9_DefectCount = df9_DefectCount.reset_index(drop=True)

# %%
df9_DefectCount
# Out:
#                     Date  \
# 0    2021-10-01 23:00:00
# 1    2021-01-15 07:00:00
# 2    2021-01-15 07:00:00
# 3    2021-01-15 11:00:00
# 4    2021-01-15 11:00:00
# ...                  ...
# 1297 2021-01-12 07:00:00
# 1298 2021-01-12 07:00:00
# 1299 2021-01-12 11:00:00
# 1300 2021-01-12 11:00:00
# 1301 2021-03-12 01:00:00
#
#       DCS_160TPD_CHIMANY_DRAFT_PRESSURE_MEASURMENT_CHMYDRFTPTAI32  \
# 0                                            -53.807611
# 1                                            -50.677260
# 2                                            -50.677260
# 3                                            -50.569284
# 4                                            -50.569284
# ...                                                 ...
# 1297                                         -50.282535
# 1298                                         -50.282535
# 1299                                         -50.911588
# 1300                                         -50.911588
# ...

# %%
df9_DefectCount.to_csv("Flat_File_Forehearth_Level_Defect_Count_J13.csv")
